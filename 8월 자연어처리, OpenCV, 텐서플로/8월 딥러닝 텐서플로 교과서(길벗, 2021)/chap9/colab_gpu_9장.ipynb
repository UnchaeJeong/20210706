# %%
#9.1.1 자연어처리 용어 및 프로세스

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk) (1.15.0)

# %%
import nltk
nltk.download("popular")
text=nltk.word_tokenize("Is it possible distinguishing cats and dogs")
text
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/omw.zip.
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet.zip.
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# ['Is', 'it', 'possible', 'distinguishing', 'cats', 'and', 'dogs']

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
nltk.pos_tag(text)
# Out:
# [('Is', 'VBZ'),
#  ('it', 'PRP'),
#  ('possible', 'JJ'),
#  ('distinguishing', 'VBG'),
#  ('cats', 'NNS'),
#  ('and', 'CC'),
#  ('dogs', 'NNS')]

# %%
# 9.1.2 자연어처리를 위한 라이브러리
# NLTK

# %%
import nltk
nltk.download('punkt')
string1="my favorite subject is math"
string2="my favorite subject is math, english, economic and computer science"
nltk.word_tokenize(string1)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['my', 'favorite', 'subject', 'is', 'math']

# %%
nltk.word_tokenize(string2)
# Out:
# ['my',
#  'favorite',
#  'subject',
#  'is',
#  'math',
#  ',',
#  'english',
#  ',',
#  'economic',
#  'and',
#  'computer',
#  'science']

# %%
# KoNLPy

# !pip install konlpy

# %%
from konlpy.tag import Komoran
komoran = Komoran()
print(komoran.morphs('딥러닝이 쉽나요? 어렵나요?'))
# Out:
# ['딥러닝이', '쉽', '나요', '?', '어렵', '나요', '?']

# %%
print(komoran.pos('소파 위에 있는 것이 고양이인가요? 강아지인가요?'))
# Out:
# [('소파', 'NNP'), ('위', 'NNG'), ('에', 'JKB'), ('있', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('이', 'JKS'), ('고양이', 'NNG'), ('이', 'VCP'), ('ㄴ가요', 'EF'), ('?', 'SF'), ('강아지', 'NNG'), ('이', 'VCP'), ('ㄴ가요', 'EF'), ('?', 'SF')]

# %%
#9.2 전처리
#9.2.1 결측치 확인하기

# %%
from google.colab import files # 데이터 불러오기
file_uploaded=files.upload()

import pandas as pd
df = pd.read_csv('class2.csv')
df
# Out:
#      <input type="file" id="files-0548d59d-8c27-4a79-94fa-80c1537e3590" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0548d59d-8c27-4a79-94fa-80c1537e3590">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving class2.csv to class2.csv
#    Unnamed: 0      id tissue class class2      x      y      r
# 0           0  mdb000      C  CIRC      N  535.0  475.0  192.0
# 1           1  mdb001      A  CIRA      N  433.0  268.0   58.0
# 2           2  mdb002      A  CIRA      I    NaN    NaN    NaN
# 3           3  mdb003      C  CIRC      B    NaN    NaN    NaN
# 4           4  mdb004      F  CIRF      I  488.0  145.0   29.0
# 5           5  mdb005      F  CIRF      B  544.0  178.0   26.0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# id            0
# tissue        0
# class         0
# class2        0
# x             2
# y             2
# r             2
# dtype: int64

# %%
df.isnull().sum() / len(df)
# Out:
# Unnamed: 0    0.000000
# id            0.000000
# tissue        0.000000
# class         0.000000
# class2        0.000000
# x             0.333333
# y             0.333333
# r             0.333333
# dtype: float64

# %%
df = df.dropna(how='all')
print(df)
# Out:
#    Unnamed: 0      id tissue class class2      x      y      r
# 0           0  mdb000      C  CIRC      N  535.0  475.0  192.0
# 1           1  mdb001      A  CIRA      N  433.0  268.0   58.0
# 2           2  mdb002      A  CIRA      I    NaN    NaN    NaN
# 3           3  mdb003      C  CIRC      B    NaN    NaN    NaN
# 4           4  mdb004      F  CIRF      I  488.0  145.0   29.0
# 5           5  mdb005      F  CIRF      B  544.0  178.0   26.0

# %%
df1 = df.dropna()
print(df1)
# Out:
#    Unnamed: 0      id tissue class class2      x      y      r
# 0           0  mdb000      C  CIRC      N  535.0  475.0  192.0
# 1           1  mdb001      A  CIRA      N  433.0  268.0   58.0
# 4           4  mdb004      F  CIRF      I  488.0  145.0   29.0
# 5           5  mdb005      F  CIRF      B  544.0  178.0   26.0

# %%
df2=df.fillna(0)
print(df2)
# Out:
#    Unnamed: 0      id tissue class class2      x      y      r
# 0           0  mdb000      C  CIRC      N  535.0  475.0  192.0
# 1           1  mdb001      A  CIRA      N  433.0  268.0   58.0
# 2           2  mdb002      A  CIRA      I    0.0    0.0    0.0
# 3           3  mdb003      C  CIRC      B    0.0    0.0    0.0
# 4           4  mdb004      F  CIRF      I  488.0  145.0   29.0
# 5           5  mdb005      F  CIRF      B  544.0  178.0   26.0

# %%
df['x'].fillna(df['x'].mean(), inplace=True)
print(df)
# Out:
#    Unnamed: 0      id tissue class class2      x      y      r
# 0           0  mdb000      C  CIRC      N  535.0  475.0  192.0
# 1           1  mdb001      A  CIRA      N  433.0  268.0   58.0
# 2           2  mdb002      A  CIRA      I  500.0    NaN    NaN
# 3           3  mdb003      C  CIRC      B  500.0    NaN    NaN
# 4           4  mdb004      F  CIRF      I  488.0  145.0   29.0
# 5           5  mdb005      F  CIRF      B  544.0  178.0   26.0

# %%
#9.2.2 토큰화

# %%
from nltk import sent_tokenize
text_sample = 'Natural Language Processing, or NLP, is the process of extracting the meaning, or intent, behind human language. In the field of Conversational artificial intelligence (AI), NLP allows machines and applications to understand the intent of human language inputs, and then generate appropriate responses, resulting in a natural conversation flow.'
tokenized_sentences = sent_tokenize(text_sample)
print(tokenized_sentences)
# Out:
# ['Natural Language Processing, or NLP, is the process of extracting the meaning, or intent, behind human language.', 'In the field of Conversational artificial intelligence (AI), NLP allows machines and applications to understand the intent of human language inputs, and then generate appropriate responses, resulting in a natural conversation flow.']

# %%
from nltk import word_tokenize
sentence = " This book is for deep learning learners"
words = word_tokenize(sentence)
print(words)
# Out:
# ['This', 'book', 'is', 'for', 'deep', 'learning', 'learners']

# %%
from nltk.tokenize import WordPunctTokenizer  
sentence = "it’s nothing that you don’t already know except most people aren’t aware of how their inner world works."
words = WordPunctTokenizer().tokenize(sentence)
print(words)
# Out:
# ['it', '’', 's', 'nothing', 'that', 'you', 'don', '’', 't', 'already', 'know', 'except', 'most', 'people', 'aren', '’', 't', 'aware', 'of', 'how', 'their', 'inner', 'world', 'works', '.']

# %%
from tensorflow.keras.preprocessing.text import text_to_word_sequence
sentence = "it’s nothing that you don’t already know except most people aren’t aware of how their inner world works."
words = text_to_word_sequence(sentence)
print(words)
# Out:
# ['it’s', 'nothing', 'that', 'you', 'don’t', 'already', 'know', 'except', 'most', 'people', 'aren’t', 'aware', 'of', 'how', 'their', 'inner', 'world', 'works']

# %%
#한국어 토큰화 예제

# %%
from google.colab import files # 데이터 불러오기
file_uploaded=files.upload()

import csv
from konlpy.tag import Okt
from gensim.models import word2vec

f = open(r'ratings_train.txt', 'r', encoding='utf-8')
rdr = csv.reader(f, delimiter='\t')
rdw = list(rdr)
f.close()
# Out:
#      <input type="file" id="files-48b07359-f167-464e-a5cb-179c1a1e801d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-48b07359-f167-464e-a5cb-179c1a1e801d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ratings_train.txt to ratings_train.txt

# %%
twitter = Okt()

result = []
for line in rdw:
    malist = twitter.pos( line[1], norm=True, stem=True)
    r = []
    for word in malist:
        if not word[1] in ["Josa","Eomi","Punctuation"]:
            r.append(word[0])
    rl = (" ".join(r)).strip()
    result.append(rl)
    print(rl)

# %%
with open("NaverMovie.nlp",'w', encoding='utf-8') as fp:
    fp.write("\n".join(result))

# %%
mData = word2vec.LineSentence("NaverMovie.nlp")
mModel =word2vec.Word2Vec(mData, size=200, window=10, hs=1, min_count=2, sg=1)
mModel.save("NaverMovie.model")

# %%
#9.2.3 불용어 제거

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')
from nltk.tokenize import word_tokenize

sample_text = "One of the first things that we ask ourselves is what are the pros and cons of any task we perform."
text_tokens = word_tokenize(sample_text)

tokens_without_sw = [word for word in text_tokens if not word in stopwords.words('english')]
print("불용어 제거 미적용:", text_tokens, '\n')
print("불용어 제거 적용:",tokens_without_sw)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 불용어 제거 미적용: ['One', 'of', 'the', 'first', 'things', 'that', 'we', 'ask', 'ourselves', 'is', 'what', 'are', 'the', 'pros', 'and', 'cons', 'of', 'any', 'task', 'we', 'perform', '.']
#
# 불용어 제거 적용: ['One', 'first', 'things', 'ask', 'pros', 'cons', 'task', 'perform', '.']

# %%
#9.2.4 어간 추출

# %%
#포터 알고리즘
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

print(stemmer.stem('obesses'),stemmer.stem('obssesed'))
print(stemmer.stem('standardizes'),stemmer.stem('standardization'))
print(stemmer.stem('national'), stemmer.stem('nation'))
print(stemmer.stem('absentness'), stemmer.stem('absently'))
print(stemmer.stem('tribalical'), stemmer.stem('tribalicalized'))
# Out:
# obess obsses
# standard standard
# nation nation
# absent absent
# tribal tribalic

# %%
#랭커스터 알고리즘
from nltk.stem import LancasterStemmer
stemmer = LancasterStemmer()

print(stemmer.stem('obsesses'),stemmer.stem('obsessed'))
print(stemmer.stem('standardizes'),stemmer.stem('standardization'))
print(stemmer.stem('national'), stemmer.stem('nation'))
print(stemmer.stem('absentness'), stemmer.stem('absently'))
print(stemmer.stem('tribalical'), stemmer.stem('tribalicalized'))
# Out:
# obsess obsess
# standard standard
# nat nat
# abs abs
# trib trib

# %%
#표제어 추출(Lemmatization)
import nltk
nltk.download('wordnet')

from nltk.stem import WordNetLemmatizer
lemma = WordNetLemmatizer()

print(stemmer.stem('obsesses'),stemmer.stem('obsessed'))
print(lemma.lemmatize('standardizes'),lemma.lemmatize('standardization'))
print(lemma.lemmatize('national'), lemma.lemmatize('nation'))
print(lemma.lemmatize('absentness'), lemma.lemmatize('absently'))
print(lemma.lemmatize('tribalical'), lemma.lemmatize('tribalicalized'))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# obsess obsess
# standardizes standardization
# national nation
# absentness absently
# tribalical tribalicalized

# %%
print(lemma.lemmatize('obsesses', 'v'),lemma.lemmatize('obsessed','a'))
print(lemma.lemmatize('standardizes','v'),lemma.lemmatize('standardization','n'))
print(lemma.lemmatize('national','a'), lemma.lemmatize('nation','n'))
print(lemma.lemmatize('absentness','n'), lemma.lemmatize('absently','r'))
print(lemma.lemmatize('tribalical','a'), lemma.lemmatize('tribalicalized','v'))
# Out:
# obsess obsessed
# standardize standardization
# national nation
# absentness absently
# tribalical tribalicalized

# %%
# 9.2.5정규화(Normalization)

# %%
from google.colab import files # 데이터 불러오기
file_uploaded=files.upload()

import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.python.data import Dataset
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import models
from tensorflow.keras import layers

df = pd.read_csv('covtype.csv')
x = df[df.columns[:54]]
y = df.Cover_Type

x_train, x_test, y_train, y_test = train_test_split(x, y , train_size = 0.7, random_state =  90)
model = tf.keras.Sequential([
 tf.keras.layers.Dense(64, activation='relu',                  
 input_shape=(x_train.shape[1],)),
 tf.keras.layers.Dense(64, activation='relu'),
 tf.keras.layers.Dense(8, activation='softmax')
 ])

model.compile(optimizer= tf.keras.optimizers.Adam(0.001),
                    loss='sparse_categorical_crossentropy',
                    metrics=['accuracy'])

history1 = model.fit(
 x_train, y_train,
 epochs= 26, batch_size = 60,
 validation_data = (x_test, y_test))
# Out:
#      <input type="file" id="files-828325d4-10c9-4034-abf4-61c986d35d34" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-828325d4-10c9-4034-abf4-61c986d35d34">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving covtype.csv to covtype.csv
# Epoch 1/26
# 6779/6779 [==============================] - 23s 3ms/step - loss: 10.5662 - accuracy: 0.5276 - val_loss: 1.1932 - val_accuracy: 0.6234
# Epoch 2/26
# 6779/6779 [==============================] - 17s 2ms/step - loss: 1.2254 - accuracy: 0.6298 - val_loss: 0.7596 - val_accuracy: 0.6891
# Epoch 3/26
# 6779/6779 [==============================] - 17s 2ms/step - loss: 0.8431 - accuracy: 0.6682 - val_loss: 0.7043 - val_accuracy: 0.6972
# Epoch 4/26
# 6779/6779 [==============================] - 17s 3ms/step - loss: 0.7060 - accuracy: 0.6971 - val_loss: 0.6630 - val_accuracy: 0.7214
# Epoch 5/26
# 6779/6779 [==============================] - 17s 2ms/step - loss: 0.6594 - accuracy: 0.7171 - val_loss: 0.6124 - val_accuracy: 0.7396
# Epoch 6/26
# 6779/6779 [==============================] - 17s 3ms/step - loss: 0.6302 - accuracy: 0.7286 - val_loss: 0.6033 - val_accuracy: 0.7403
# Epoch 7/26
# 6779/6779 [==============================] - 17s 2ms/step - loss: 0.6124 - accuracy: 0.7365 - val_loss: 0.6256 - val_accuracy: 0.7334
# Epoch 8/26
# 6779/6779 [==============================] - 17s 2ms/step - loss: 0.5974 - accuracy: 0.7425 - val_loss: 0.6147 - val_accuracy: 0.7354
# Epoch 9/26
# 6779/6779 [==============================] - 17s 2ms/step - loss: 0.5879 - accuracy: 0.7476 - val_loss: 0.6710 - val_accuracy: 0.7148
# Epoch 10/26
# 6779/6779 [==============================] - 16s 2ms/step - loss: 0.5840 - accuracy: 0.7489 - val_loss: 0.5740 - val_accuracy: 0.7541
# Epoch 11/26
# 6779/6779 [==============================] - 17s 3ms/step - loss: 0.5732 - accuracy: 0.7552 - val_loss: 0.5582 - val_accuracy: 0.7599
# Epoch 12/26
# 6779/6779 [==============================] - 17s 2ms/step - loss: 0.5668 - accuracy: 0.7572 - val_loss: 0.5672 - val_accuracy: 0.7564
# Epoch 13/26
# 6779/6779 [==============================] - 17s 2ms/step - loss: 0.5602 - accuracy: 0.7611 - val_loss: 0.5534 - val_accuracy: 0.7633
# Epoch 14/26
# 6779/6779 [==============================] - 17s 2ms/step - loss: 0.5604 - accuracy: 0.7602 - val_loss: 0.5500 - val_accuracy: 0.7637
# Epoch 15/26
# 6779/6779 [==============================] - 17s 3ms/step - loss: 0.5512 - accuracy: 0.7647 - val_loss: 0.5538 - val_accuracy: 0.7661
# Epoch 16/26
# 6779/6779 [==============================] - 17s 2ms/step - loss: 0.5512 - accuracy: 0.7653 - val_loss: 0.5403 - val_accuracy: 0.7704
# Epoch 17/26
# 6779/6779 [==============================] - 16s 2ms/step - loss: 0.5456 - accuracy: 0.7679 - val_loss: 0.5302 - val_accuracy: 0.7761
# Epoch 18/26
# 6779/6779 [==============================] - 16s 2ms/step - loss: 0.5454 - accuracy: 0.7680 - val_loss: 0.5393 - val_accuracy: 0.7668
# Epoch 19/26
# 6779/6779 [==============================] - 17s 2ms/step - loss: 0.5425 - accuracy: 0.7693 - val_loss: 0.5269 - val_accuracy: 0.7750
# Epoch 20/26
# 6779/6779 [==============================] - 17s 3ms/step - loss: 0.5399 - accuracy: 0.7693 - val_loss: 0.5288 - val_accuracy: 0.7769
# Epoch 21/26
# 6779/6779 [==============================] - 17s 3ms/step - loss: 0.5391 - accuracy: 0.7702 - val_loss: 0.5223 - val_accuracy: 0.7794
# Epoch 22/26
# 6779/6779 [==============================] - 18s 3ms/step - loss: 0.5367 - accuracy: 0.7721 - val_loss: 0.5167 - val_accuracy: 0.7819
# Epoch 23/26
# 6779/6779 [==============================] - 17s 3ms/step - loss: 0.5354 - accuracy: 0.7731 - val_loss: 0.5763 - val_accuracy: 0.7504
# Epoch 24/26
# 6779/6779 [==============================] - 17s 2ms/step - loss: 0.5359 - accuracy: 0.7728 - val_loss: 0.5344 - val_accuracy: 0.7734
# Epoch 25/26
# 6779/6779 [==============================] - 16s 2ms/step - loss: 0.5291 - accuracy: 0.7769 - val_loss: 0.5640 - val_accuracy: 0.7654
# Epoch 26/26
# 6779/6779 [==============================] - 17s 3ms/step - loss: 0.5333 - accuracy: 0.7746 - val_loss: 0.5435 - val_accuracy: 0.7682

# %%
from google.colab import files # 데이터 불러오기
file_uploaded=files.upload()

from sklearn import preprocessing
df = pd.read_csv('covtype.csv')
x = df[df.columns[:55]]
y = df.Cover_Type
x_train, x_test, y_train, y_test = train_test_split(x, y , train_size = 0.7, random_state =  90)


train_norm = x_train[x_train.columns[0:10]]
test_norm = x_test[x_test.columns[0:10]]


std_scale = preprocessing.StandardScaler().fit(train_norm)
x_train_norm = std_scale.transform(train_norm)


training_norm_col = pd.DataFrame(x_train_norm, index=train_norm.index, columns=train_norm.columns) 
x_train.update(training_norm_col)
print (x_train.head())


x_test_norm = std_scale.transform(test_norm)
testing_norm_col = pd.DataFrame(x_test_norm, index=test_norm.index, columns=test_norm.columns) 
x_test.update(testing_norm_col)
print (x_test.head())
# Out:
#      <input type="file" id="files-a4c1eafd-261e-40b9-9392-5e8a88c20a54" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a4c1eafd-261e-40b9-9392-5e8a88c20a54">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving covtype.csv to covtype (1).csv
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:6397: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = expressions.where(mask, this, that)
#         Elevation    Aspect     Slope  ...  Soil_Type39  Soil_Type40  Cover_Type
# 152044   0.222366 -0.228639 -0.412503  ...            0            0           2
# 363373   1.980490 -0.469989  0.255453  ...            0            1           1
# 372733  -1.081933  0.271939  0.389044  ...            0            0           3
# 572846  -1.164122 -0.157128 -0.278912  ...            0            0           2
# 114145  -0.052787  0.861906  0.255453  ...            0            0           2
#
# [5 rows x 55 columns]
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:6397: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = expressions.where(mask, this, that)
#         Elevation    Aspect     Slope  ...  Soil_Type39  Soil_Type40  Cover_Type
# 204886   0.783394 -1.310245 -0.946867  ...            0            0           1
# 116027  -0.903262 -1.006323 -0.679685  ...            0            0           2
# 328145  -0.270766 -1.095711 -0.278912  ...            0            0           2
# 579670  -1.139108 -0.961628 -0.412503  ...            0            0           3
# 41341    0.265247  0.736762 -1.347641  ...            0            0           2
#
# [5 rows x 55 columns]

# %%
model = tf.keras.Sequential([
 tf.keras.layers.Dense(64, activation='relu',                  
 input_shape=(x_train.shape[1],)),
 tf.keras.layers.Dense(64, activation='relu'),
 tf.keras.layers.Dense(8, activation=  'softmax')
 ])

model.compile(optimizer= tf.keras.optimizers.Adam(0.001),
                    loss='sparse_categorical_crossentropy',
                    metrics=['accuracy'])
history2 = model.fit(
 x_train, y_train,
 epochs= 26, batch_size = 60,
 validation_data = (x_test, y_test))
# Out:
# Epoch 1/26
# 6779/6779 [==============================] - 18s 3ms/step - loss: 0.1369 - accuracy: 0.9579 - val_loss: 6.9570e-05 - val_accuracy: 1.0000
# Epoch 2/26
# 6779/6779 [==============================] - 17s 3ms/step - loss: 3.4405e-04 - accuracy: 0.9999 - val_loss: 1.4219e-05 - val_accuracy: 1.0000
# Epoch 3/26
# 6779/6779 [==============================] - 17s 3ms/step - loss: 6.6614e-05 - accuracy: 1.0000 - val_loss: 4.4874e-06 - val_accuracy: 1.0000
# Epoch 4/26
# 6779/6779 [==============================] - 16s 2ms/step - loss: 1.7005e-04 - accuracy: 1.0000 - val_loss: 1.6303e-06 - val_accuracy: 1.0000
# Epoch 5/26
# 6779/6779 [==============================] - 16s 2ms/step - loss: 3.4814e-05 - accuracy: 1.0000 - val_loss: 7.8615e-06 - val_accuracy: 1.0000
# Epoch 6/26
# 6779/6779 [==============================] - 17s 2ms/step - loss: 2.3881e-06 - accuracy: 1.0000 - val_loss: 6.1646e-05 - val_accuracy: 1.0000
# Epoch 7/26
# 6779/6779 [==============================] - 17s 3ms/step - loss: 3.3003e-04 - accuracy: 0.9999 - val_loss: 3.2106e-05 - val_accuracy: 1.0000
# Epoch 8/26
# 6779/6779 [==============================] - 17s 3ms/step - loss: 9.4980e-05 - accuracy: 1.0000 - val_loss: 2.4406e-06 - val_accuracy: 1.0000
# Epoch 9/26
# 6779/6779 [==============================] - 16s 2ms/step - loss: 1.5261e-04 - accuracy: 0.9999 - val_loss: 9.9539e-07 - val_accuracy: 1.0000
# Epoch 10/26
# 6779/6779 [==============================] - 17s 2ms/step - loss: 6.0355e-07 - accuracy: 1.0000 - val_loss: 4.7561e-08 - val_accuracy: 1.0000
# Epoch 11/26
# 6779/6779 [==============================] - 17s 3ms/step - loss: 1.2930e-04 - accuracy: 1.0000 - val_loss: 3.7714e-07 - val_accuracy: 1.0000
# Epoch 12/26
# 6779/6779 [==============================] - 17s 3ms/step - loss: 2.0200e-07 - accuracy: 1.0000 - val_loss: 6.9886e-08 - val_accuracy: 1.0000
# Epoch 13/26
# 6779/6779 [==============================] - 17s 2ms/step - loss: 3.4108e-05 - accuracy: 1.0000 - val_loss: 3.0945e-07 - val_accuracy: 1.0000
# Epoch 14/26
# 6779/6779 [==============================] - 16s 2ms/step - loss: 1.0145e-07 - accuracy: 1.0000 - val_loss: 2.9191e-08 - val_accuracy: 1.0000
# Epoch 15/26
# 6779/6779 [==============================] - 17s 2ms/step - loss: 6.8853e-05 - accuracy: 1.0000 - val_loss: 2.4571e-07 - val_accuracy: 1.0000
# Epoch 16/26
# 6779/6779 [==============================] - 17s 2ms/step - loss: 2.5023e-07 - accuracy: 1.0000 - val_loss: 1.8934e-07 - val_accuracy: 1.0000
# Epoch 17/26
# 6779/6779 [==============================] - 17s 2ms/step - loss: 2.6801e-05 - accuracy: 1.0000 - val_loss: 1.0134e-06 - val_accuracy: 1.0000
# Epoch 18/26
# 6779/6779 [==============================] - 17s 2ms/step - loss: 8.6559e-08 - accuracy: 1.0000 - val_loss: 3.3332e-08 - val_accuracy: 1.0000
# Epoch 19/26
# 6779/6779 [==============================] - 16s 2ms/step - loss: 1.6856e-05 - accuracy: 1.0000 - val_loss: 6.4720e-05 - val_accuracy: 1.0000
# Epoch 20/26
# 6779/6779 [==============================] - 16s 2ms/step - loss: 4.4088e-05 - accuracy: 1.0000 - val_loss: 3.9687e-08 - val_accuracy: 1.0000
# Epoch 21/26
# 6779/6779 [==============================] - 16s 2ms/step - loss: 2.1354e-08 - accuracy: 1.0000 - val_loss: 1.2982e-08 - val_accuracy: 1.0000
# Epoch 22/26
# 6779/6779 [==============================] - 17s 2ms/step - loss: 1.0034e-04 - accuracy: 1.0000 - val_loss: 4.0488e-05 - val_accuracy: 1.0000
# Epoch 23/26
# 6779/6779 [==============================] - 16s 2ms/step - loss: 1.2554e-04 - accuracy: 1.0000 - val_loss: 3.5525e-06 - val_accuracy: 1.0000
# Epoch 24/26
# 6779/6779 [==============================] - 16s 2ms/step - loss: 4.1542e-08 - accuracy: 1.0000 - val_loss: 4.6543e-08 - val_accuracy: 1.0000
# Epoch 25/26
# 6779/6779 [==============================] - 16s 2ms/step - loss: 4.9511e-05 - accuracy: 1.0000 - val_loss: 2.4401e-06 - val_accuracy: 1.0000
# Epoch 26/26
# 6779/6779 [==============================] - 16s 2ms/step - loss: 4.4408e-07 - accuracy: 1.0000 - val_loss: 4.6640e-08 - val_accuracy: 1.0000
