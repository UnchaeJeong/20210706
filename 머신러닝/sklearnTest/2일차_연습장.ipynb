# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression, SGDRegressor
from sklearn.metrics import r2_score# 선형 모델(Linear Models)
from sklearn.datasets import load_boston, load_iris
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family']='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
df_car = pd.read_csv('data/cars.csv')
df_car.columns = ['speed','dist']
df_car
# df_car.shape
# Out:
#     speed  dist
# 0       4     2
# 1       4    10
# 2       7     4
# 3       7    22
# 4       8    16
# 5       9    10
# 6      10    18
# 7      10    26
# 8      10    34
# 9      11    17
# 10     11    28
# 11     12    14
# 12     12    20
# 13     12    24
# 14     12    28
# 15     13    26
# 16     13    34
# 17     13    34
# 18     13    46
# 19     14    26
# 20     14    36
# 21     14    60
# 22     14    80
# 23     15    20
# 24     15    26
# 25     15    54
# 26     16    32
# 27     16    40
# 28     17    32
# 29     17    40
# 30     17    50
# 31     18    42
# 32     18    56
# 33     18    76
# 34     18    84
# 35     19    36
# 36     19    46
# 37     19    68
# 38     20    32
# 39     20    48
# 40     20    52
# 41     20    56
# 42     20    64
# 43     22    66
# 44     23    54
# 45     24    70
# 46     24    92
# 47     24    93
# 48     24   120
# 49     25    85

# %%
x_data = df_car[['speed']] # DataFrame 인가?
y_data = df_car['dist'] # label

# %%
modelSGD = SGDRegressor(max_iter=200, alpha=0.001, early_stopping=True, verbose=0)
modelSGD.fit(x_data, y_data)
# Out:
# SGDRegressor(alpha=0.001, early_stopping=True, max_iter=200)

# %%
modelSGD.coef_
# Out:
# array([2.61735346])

# %%
modelSGD.intercept_
# Out:
# array([-1.78179365])

# %%
y_predict = modelSGD.predict(x_data)
plt.scatter(x_data,y_data)
plt.plot(x_data, y_predict, 'r')
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score 
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family']='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
df_car = pd.read_csv('data/cars.csv')
df_car.columns = ['speed', 'dist']
df_car.head()
# Out:
#    speed  dist
# 0      4     2
# 1      4    10
# 2      7     4
# 3      7    22
# 4      8    16

# %%
x_data = df_car[['speed']]
y_data = df_car['dist']

# %%
df_car.corr()
# Out:
#           speed      dist
# speed  1.000000  0.806895
# dist   0.806895  1.000000

# %%
model_car = LinearRegression()
model_car.fit(x_data, y_data)
# Out:
# LinearRegression()

# %%
model_car.coef_
# Out:
# array([3.93240876])

# %%
model_car.intercept_
# Out:
# -17.57909489051095

# %%
y_predict = model_car.predict(x_data)
r2_score(y_data, y_predict)
# Out:
# 0.6510793807582509

# %%
df = pd.read_csv('data/data-01.csv')
df.columns= ['q1','q2','midterm','final']
df.head()
# Out:
#    q1  q2  midterm  final
# 0  93  88       93    185
# 1  89  91       90    180
# 2  96  98      100    196
# 3  73  66       70    142
# 4  53  46       55    101

# %%
x_data = df.iloc[:,:-1]
x_data.head()
# Out:
#    q1  q2  midterm
# 0  93  88       93
# 1  89  91       90
# 2  96  98      100
# 3  73  66       70
# 4  53  46       55

# %%
y_data = df.iloc[:,[-1]]
y_data.head()
# Out:
#    final
# 0    185
# 1    180
# 2    196
# 3    142
# 4    101

# %% [markdown]
# ###### 이거의 정확한 뜻이 뭐지? 선형회귀모델에 값을 집어넣는다는 거 같은데 머리속으로 안그려지네

# %%
model_lr =LinearRegression()
model_lr.fit(x_data,y_data)
# Out:
# LinearRegression()

# %%
model_lr.coef_
# Out:
# array([[0.3512051 , 0.54898899, 1.16469984]])

# %%
model_lr.intercept_
# Out:
# array([-4.22526606])

# %%
x_data.shape
# Out:
# (24, 3)

# %%
y_data.shape
# Out:
# (24, 1)

# %% [markdown]
# ###### 이게 어떻게 25x3 * 3x1이야..? y_data 24x1나오는데?

# %%
model_lr.score(x_data,y_data)
# Out:
# 0.9896129198609613

# %%
p = model_lr.predict(x_data)
p.shape
# Out:
# (24, 1)

# %%
plt.plot(y_data,label='final 데이터')
plt.plot(p, 'r--',label='예측 데이터')
plt.show()

# %%
boston = load_boston()

# %%
boston
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#          4.9800e+00],
#         [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#          9.1400e+00],
#         [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#          4.0300e+00],
#         ...,
#         [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          5.6400e+00],
#         [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#          6.4800e+00],
#         [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          7.8800e+00]]),
#  'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#         18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#         15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#         13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
# ...

# %%
boston.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
boston['data']
boston['data'].shape
# Out:
# (506, 13)

# %%
boston['target']
boston['target'].shape
# Out:
# (506,)

# %%
boston['feature_names']
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
df_boston = pd.DataFrame(boston['data'],columns = boston['feature_names'])
df_boston['MEDV'] = boston['target']
df_boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
x_data = df_boston.iloc[:,:-1]
y_data = df_boston.iloc[:,[-1]]

boston_lr = LinearRegression()
boston_lr.fit(x_data,y_data)
# Out:
# LinearRegression()

# %%
boston_lr.predict([[0.02731, 0.0, 7.07, 0.0, 0.469, 6.421, 78.9, 4.9671, 2.0, 242.0, 17.8, 396.90, 9.14]])
# Out:
# array([[25.02556238]])

# %%
x_data.values
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
scaleX = StandardScaler()
x_dataS = scaleX.fit_transform(x_data.values)

# %%
x_dataS
# Out:
# array([[-0.41978194,  0.28482986, -1.2879095 , ..., -1.45900038,
#          0.44105193, -1.0755623 ],
#        [-0.41733926, -0.48772236, -0.59338101, ..., -0.30309415,
#          0.44105193, -0.49243937],
#        [-0.41734159, -0.48772236, -0.59338101, ..., -0.30309415,
#          0.39642699, -1.2087274 ],
#        ...,
#        [-0.41344658, -0.48772236,  0.11573841, ...,  1.17646583,
#          0.44105193, -0.98304761],
#        [-0.40776407, -0.48772236,  0.11573841, ...,  1.17646583,
#          0.4032249 , -0.86530163],
#        [-0.41500016, -0.48772236,  0.11573841, ...,  1.17646583,
#          0.44105193, -0.66905833]])

# %%
y_data.values
# Out:
# array([[24. ],
#        [21.6],
#        [34.7],
#        [33.4],
#        [36.2],
#        [28.7],
#        [22.9],
#        [27.1],
#        [16.5],
#        [18.9],
#        [15. ],
#        [18.9],
#        [21.7],
#        [20.4],
#        [18.2],
#        [19.9],
#        [23.1],
#        [17.5],
#        [20.2],
#        [18.2],
#        [13.6],
#        [19.6],
#        [15.2],
#        [14.5],
#        [15.6],
#        [13.9],
#        [16.6],
#        [14.8],
#        [18.4],
#        [21. ],
#        [12.7],
#        [14.5],
#        [13.2],
#        [13.1],
#        [13.5],
#        [18.9],
#        [20. ],
#        [21. ],
#        [24.7],
#        [30.8],
#        [34.9],
#        [26.6],
#        [25.3],
#        [24.7],
#        [21.2],
#        [19.3],
#        [20. ],
#        [16.6],
#        [14.4],
#        [19.4],
#        [19.7],
#        [20.5],
#        [25. ],
#        [23.4],
#        [18.9],
#        [35.4],
#        [24.7],
#        [31.6],
# ...

# %%
result = train_test_split(x_dataS, y_data.values, test_size=0.2, random_state=1)

# %% [markdown]
# ###### 이건 뭐지..?

# %%
a,b,c = [1,2,3]

# %%
result
# Out:
# [array([[-0.40405061, -0.48772236, -0.61672651, ..., -0.2568579 ,
#           0.29270416, -0.95921806],
#         [-0.40254357,  0.58526684, -0.87644514, ...,  0.57539459,
#           0.37285362, -0.81203559],
#         [ 1.53592609, -0.48772236,  1.01599907, ...,  0.80657583,
#           0.44105193,  2.54512652],
#         ...,
#         [ 0.26283202, -0.48772236,  1.01599907, ...,  0.80657583,
#           0.44105193,  0.94153844],
#         [-0.38206188, -0.48772236, -0.72032214, ..., -0.48803915,
#           0.22012011, -0.24853698],
#         [-0.41119127, -0.48772236, -0.75534039, ...,  0.34421334,
#           0.44105193, -0.54430367]]),
#  array([[-0.41477789,  0.92862338, -1.30687771, ..., -0.02567665,
#           0.44105193, -0.71811916],
#         [-0.41755805,  1.87285388, -1.07342276, ..., -0.39556665,
#           0.44105193, -0.76717998],
#         [-0.39383653, -0.48772236, -0.61672651, ..., -0.2568579 ,
#           0.3954402 ,  0.86163938],
#         ...,
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x_dataS, y_data.values, test_size=0.2 ,  random_state=1  )

# %%
x_train
# Out:
# array([[-0.40405061, -0.48772236, -0.61672651, ..., -0.2568579 ,
#          0.29270416, -0.95921806],
#        [-0.40254357,  0.58526684, -0.87644514, ...,  0.57539459,
#          0.37285362, -0.81203559],
#        [ 1.53592609, -0.48772236,  1.01599907, ...,  0.80657583,
#          0.44105193,  2.54512652],
#        ...,
#        [ 0.26283202, -0.48772236,  1.01599907, ...,  0.80657583,
#          0.44105193,  0.94153844],
#        [-0.38206188, -0.48772236, -0.72032214, ..., -0.48803915,
#          0.22012011, -0.24853698],
#        [-0.41119127, -0.48772236, -0.75534039, ...,  0.34421334,
#          0.44105193, -0.54430367]])

# %%
x_train.shape
# Out:
# (404, 13)

# %%
x_test.shape
# Out:
# (102, 13)

# %%
y_train.shape
# Out:
# (404, 1)

# %%
y_test.shape
# Out:
# (102, 1)

# %%
modelSGD = SGDRegressor(verbose=1)
modelSGD.fit(x_train, y_train)
# Out:
# -- Epoch 1
# Norm: 4.20, NNZs: 13, Bias: 15.835085, T: 404, Avg. loss: 101.368571
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 4.69, NNZs: 13, Bias: 19.639279, T: 808, Avg. loss: 24.094783
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 5.13, NNZs: 13, Bias: 21.187124, T: 1212, Avg. loss: 14.685085
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 5.21, NNZs: 13, Bias: 21.902127, T: 1616, Avg. loss: 12.567961
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 5.56, NNZs: 13, Bias: 22.237995, T: 2020, Avg. loss: 11.927838
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 5.60, NNZs: 13, Bias: 22.435668, T: 2424, Avg. loss: 11.753113
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 5.69, NNZs: 13, Bias: 22.512305, T: 2828, Avg. loss: 11.654846
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 5.71, NNZs: 13, Bias: 22.538389, T: 3232, Avg. loss: 11.541138
# Total training time: 0.00 seconds.
# -- Epoch 9
# ...

# %%
modelSGD.score(x_train, y_train)
# Out:
# 0.7287699547106616

# %%
modelSGD.score(x_test, y_test)
# Out:
# 0.7614260199705623

# %%
modelSGD.predict(x_test[[0]])
# Out:
# array([32.26678356])

# %%
boston_lr.predict([[0.02731, 0.0, 7.07, 0.0, 0.469, 6.421, 78.9, 4.9671, 2.0, 242.0, 17.8, 396.90, 9.14]])
# Out:
# array([[25.02556238]])

# %%
xd = scaleX.transform([[0.02731, 0.0, 7.07, 0.0, 0.469, 6.421, 78.9, 4.9671, 2.0, 242.0, 17.8, 396.90, 9.14]])
# 롸? 이건 리얼 뭐지 스케일링되지 않은 값으로 트랜스폼해줘야함.

# %%
modelSGD.predict(xd)
# Out:
# array([24.9042265])
