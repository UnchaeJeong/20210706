# %%
plt.plot([1,2,3,4], [1,4,7,9])
plt.show()

# %%
a = plt.plot([1,2,3,4])
a+=(plt.plot([0.5,1.1,2.1,3.4]))
# print(a)
plt.show()

# %%
t = np.arange(0., 5., 0.2)
a = plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
years = [x for x in range(1950, 2011, 10)]
print(years)

gdp = [y for y in np.random.randint(300,10000, size=7)]
print(gdp)

plt.plot(years, gdp, color='green', marker='o', linestyle='solid')
plt.show()
# Out:
# [1950, 1960, 1970, 1980, 1990, 2000, 2010]
# [3549, 5467, 7257, 1970, 2084, 6603, 2484]

# %%
plt.plot(years, gdp, color='b')

plt.show()

# %%
plt.plot(years, gdp, marker='o', markersize=6, markeredgewidth=2,
        markeredgecolor='red', markerfacecolor='green')
plt.show()

# %%
plt.plot([1,2,3,4], 'ro')
plt.show()

# %%
x = [1,2,3]
y = [1,4,9]
plt.plot(x, y, color='green', linestyle='dashed', marker='o',
        markerfacecolor='blue', markersize=12)
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16], 'r-')
plt.show()
plt.plot([1,2,3,4],[1,3,2,11], 'b--')
plt.show()

# %%
plt.plot(x, y, 'ro')
plt.show()

# %%
plt.plot(x, y, linewidth=3.0)
plt.show()

# %%
a = b = np.arange(0,3,.02)
c = np.exp(a)
d = c[::-1]

plt.plot(a, c, 'k--', label='Model length')
plt.plot(a, d, 'b-', label='Data length')
plt.plot(a, c+d, 'r', label = 'Total message length')

plt.legend()
plt.show()

# %%
print(x, y)
# Out:
# [1, 2, 3] [1, 4, 9]

# %%
x = np.array(x)
y = np.array(y)

# %%
line1, line2 = plt.plot(x, y, '-', x, y*2, '--')

plt.setp(line1, color='r', linewidth=2.0)

plt.show()

# %%
a = plt.plot([1,2,3,4], [1,4,9,16], 'ro')
b = plt.axis([0, 6, 0, 20])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
N = 5
menMeans = (20,35,30, 35, 27)
ind = np.arange(N)
print(ind)
plt.bar(ind, menMeans)
plt.title('Scores by group and gender')
plt.ylabel('Scores')
plt.xlabel('The number of people')
plt.xticks(ind + width/2., ('G1','G2','G3','G4','G5'))
plt.yticks(np.arange(0,81,10))
plt.legend( ('Men'))

plt.show()
# Out:
# [0 1 2 3 4]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-97cac3cc3e20> in <module>
#       9 plt.ylabel('Scores')
#      10 plt.xlabel('The number of people')
# ---> 11 plt.xticks('G1','G2','G3','G4','G5')
#      12 plt.yticks(np.arange(0,81,10))
#      13 plt.legend( ('Men'))
#
# TypeError: xticks() takes from 0 to 2 positional arguments but 5 were given

# %%
x = [1,2,3,4,5]
y=[1,4,8,16,25]
plt.plot(x,y)

plt.title('x,y')
plt.xlabel('x axis')
plt.ylabel('y axis')

plt.xlim(0.0, 7.0)
plt.ylim(0.0, 30.)

plt.show()

# %%
y = np.random.normal(loc=0.5, scale=0.4, size=1000)
y = y[(y>0) & (y<1)]
y.sort()
x = np.arange(len(y))

plt.figure(1)
plt.subplot(221)
plt.plot(x,y)
plt.yscale('linear')
plt.title('linear')
plt.grid(False)

plt.subplot(222)
plt.plot(x, y)
plt.yscale('log')
plt.title('log')
plt.grid(True)
plt.show()

# %%
plt.plot(x,y)
plt.legend(['A simple line'])
plt.show()
