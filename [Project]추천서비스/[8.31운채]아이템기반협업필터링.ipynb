# %% [markdown]
# # 목표 : 비슷한 아티스트를 가진 플레이리스트들을 그룹화해보자
#
# ---

# %% [markdown]
# ## 라이브러리, 데이터 불러오기

# %%
import os
import json
import numpy as np
import pandas as pd
import scipy.sparse as spr

# %%
with open('data/train.json',encoding='utf-8-sig') as f:
    train_dict = json.load(f)
    
with open('data/song_meta.json',encoding='utf-8-sig') as f:
    song_dict = json.load(f)
    
with open('data/genre_gn_all.json',encoding='utf-8-sig') as f:
    genre_dict = json.load(f)
    
train_df = pd.DataFrame.from_dict(train_dict)
song_df = pd.DataFrame.from_dict(song_dict)

# %%
# 데이터 확인
display(train_df.head(1))
display(song_df.head(1))
type(train_df), type(song_df)
# Out:
#   tags     id plylst_title                                              songs  \
# 0  [락]  61281      여행같은 음악  [525514, 129701, 383374, 562083, 297861, 13954...
#
#    like_cnt                updt_date
# 0        71  2013-12-19 18:36:19.000
#   song_gn_dtl_gnr_basket issue_date                    album_name  album_id  \
# 0               [GN0901]   20140512  불후의 명곡 - 7080 추억의 얄개시대 팝송베스트   2255639
#
#   artist_id_basket song_name song_gn_gnr_basket artist_name_basket  id
# 0           [2727]  Feelings           [GN0900]  [Various Artists]   0
# (pandas.core.frame.DataFrame, pandas.core.frame.DataFrame)

# %%
genre_gn_all = pd.read_json('data/genre_gn_all.json', typ = 'series')

# %%
pd.DataFrame(genre_gn_all).T
# Out:
#   GN0100  GN0101 GN0102 GN0103 GN0104 GN0105 GN0200  GN0201 GN0202 GN0203  \
# 0    발라드  세부장르전체    '80    '90    '00   '10-     댄스  세부장르전체    '80    '90
#
#    ...   GN2802    GN2803 GN2804 GN2805 GN2806 GN2900  GN2901 GN2902 GN2903  \
# 0  ...  ASMR/자연  힐링/명상/요가    집중력   숙면유도   반려동물    뮤지컬  세부장르전체  국내뮤지컬  국외뮤지컬
#
#   GN3000
# 0  크리스마스
#
# [1 rows x 254 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## 사용할 컬럼 추리기
# - 내가 사용할 컬럼은 train_df의 `id`, `plylst_title`, `songs` 와  song_df의 `song_id`, `artist_name_basket`
# - `songs`와 `song_id`를 기준으로 song_df의 `artist_name_basket`를 train_df에 조인시키기 위한 사전작업임.

# %%
train_df.drop(['tags','like_cnt','updt_date'], axis=1, inplace=True)

# %%
train_df.head()
# Out:
#        id           plylst_title  \
# 0   61281                여행같은 음악
# 1   10532                요즘 너 말야
# 2   76951  편하게, 잔잔하게 들을 수 있는 곡.-
# 3  147456  크리스마스 분위기에 흠뻑 취하고 싶을때
# 4   27616               추억의 노래 ㅋ
#
#                                                songs
# 0  [525514, 129701, 383374, 562083, 297861, 13954...
# 1  [432406, 675945, 497066, 120377, 389529, 24427...
# 2  [83116, 276692, 166267, 186301, 354465, 256598...
# 3  [394031, 195524, 540149, 287984, 440773, 10033...
# 4  [159327, 553610, 5130, 645103, 294435, 100657,...

# %%
# train_df['songs']의 값인 리스트 속 int를 str로 바꿔주는 함수.
# 사용하진 않아서 주석처리

# train_df['songs_str'] = train_df['songs'].apply(lambda x : list(map(str, x)))
# train_df.drop(['songs'], axis=1, inplace=True)
train_df.head(1)

# %%
song_df.drop(['song_gn_dtl_gnr_basket','issue_date','album_name','album_id','song_gn_gnr_basket'],axis=1,inplace=True)
song_df['song_id'] = song_df['id']
song_df.drop('id',axis=1,inplace=True)
song_df.head(1)
# Out:
#   artist_id_basket song_name artist_name_basket  song_id
# 0           [2727]  Feelings  [Various Artists]        0

# %% [markdown]
# ## `Artist`를 `songs`에 매핑시키기
# - song_meta에 `artist_name_basket`가 있고 train_df에 `song_id`가 있음
# - song_meta와 train데이터를 조인 시킬 때 `songs`컬럼과 매칭될 수 있도록 `artist_name_basket`을 리스트 형식으로 조인시킴.
# - 이 결과 각 곡에 아티스트를 매핑하는 것보다 데이터 프레임이 방대해지는 것을 방지할 수 있었음.

# %%
display(train_df.head(1))
display(song_df.head(1))
# Out:
#       id plylst_title                                              songs
# 0  61281      여행같은 음악  [525514, 129701, 383374, 562083, 297861, 13954...
#   artist_id_basket song_name artist_name_basket  song_id
# 0           [2727]  Feelings  [Various Artists]        0

# %%
def match_artist(x):
    temp_list = []
    for song_ids in x:
#         print(song_dict[song_ids]['artist_name_basket'])
        temp_list.extend(song_dict[song_ids]['artist_name_basket'])

    temp_list = list(set(temp_list))
    return temp_list

train_df['artist_list'] = train_df['songs'].map(match_artist)

# %%
train_df.head(1)
# Out:
#             id                       plylst_title  \
# 0        61281                            여행같은 음악
# 1        10532                            요즘 너 말야
# 2        76951              편하게, 잔잔하게 들을 수 있는 곡.-
# 3       147456              크리스마스 분위기에 흠뻑 취하고 싶을때
# 4        27616                           추억의 노래 ㅋ
# ...        ...                                ...
# 115066  120325                      METAL E'SM #2
# 115067  106976     빠른 리스너를 위한 따끈따끈한 최신 인기 EDM 모음!
# 115068   11343              #1. 눈물이 앞을 가리는 나의_이야기
# 115069  131982  퇴근 버스에서 편히 들으면서 하루를 마무리하기에 좋은 POP
# 115070  100389                FAVORITE POPSONG!!!
#
#                                                     songs  \
# 0       [525514, 129701, 383374, 562083, 297861, 13954...
# 1       [432406, 675945, 497066, 120377, 389529, 24427...
# 2       [83116, 276692, 166267, 186301, 354465, 256598...
# 3       [394031, 195524, 540149, 287984, 440773, 10033...
# 4       [159327, 553610, 5130, 645103, 294435, 100657,...
# ...                                                   ...
# 115066  [429629, 441511, 612106, 516359, 691768, 38714...
# 115067  [321330, 216057, 534472, 240306, 331098, 23288...
# 115068  [50512, 249024, 250608, 371171, 229942, 694943...
# 115069  [533534, 608114, 343608, 417140, 609009, 30217...
# 115070  [26008, 456354, 324105, 89871, 135272, 143548,...
#
#                                               artist_list
# 0       [Lily Of The Valley, Red Hot Chili Peppers, Co...
# 1       [타루, 임주연, 제이레빗(J Rabbit), 라이너스의 담요, 박명수, 이상순, ...
# 2       [달 좋은 밤, 소울사이어티, 참깨와 솜사탕, PERC%NT, 슈가볼, 김박첼라, ...
# 3       [장희원, Ku Il Oh Trio, 이석훈, Katie Lopez, Ashley ...
# 4       [유피, 핑클 (Fin.K.L), 지누션, 샵, 마로니에, 원타임, 터보, 보아 (...
# ...                                                   ...
# 115066  [Carcass, DevilDriver, Slipknot, Deicide, Arch...
# 115067  [Flatland Funk, Komes, Bsharry, Ste Ingham, Sp...
# 115068  [씨야, 가비엔제이, 윤종신, 김창기, 벤, 김진호 (SG워너비), 양희은, 나비,...
# 115069  [Angus & Julia Stone, Ben Howard, BØRNS, The S...
# 115070  [Jason Mraz, Acceptance, Mr. Probz, Paramore, ...
#
# [115071 rows x 4 columns]

# %%
train_df[['plylst_title', 'artist_list']]
# Out:
#                              plylst_title  \
# 0                                 여행같은 음악
# 1                                 요즘 너 말야
# 2                   편하게, 잔잔하게 들을 수 있는 곡.-
# 3                   크리스마스 분위기에 흠뻑 취하고 싶을때
# 4                                추억의 노래 ㅋ
# ...                                   ...
# 115066                      METAL E'SM #2
# 115067     빠른 리스너를 위한 따끈따끈한 최신 인기 EDM 모음!
# 115068              #1. 눈물이 앞을 가리는 나의_이야기
# 115069  퇴근 버스에서 편히 들으면서 하루를 마무리하기에 좋은 POP
# 115070                FAVORITE POPSONG!!!
#
#                                               artist_list
# 0       [Lily Of The Valley, Red Hot Chili Peppers, Co...
# 1       [타루, 임주연, 제이레빗(J Rabbit), 라이너스의 담요, 박명수, 이상순, ...
# 2       [달 좋은 밤, 소울사이어티, 참깨와 솜사탕, PERC%NT, 슈가볼, 김박첼라, ...
# 3       [장희원, Ku Il Oh Trio, 이석훈, Katie Lopez, Ashley ...
# 4       [유피, 핑클 (Fin.K.L), 지누션, 샵, 마로니에, 원타임, 터보, 보아 (...
# ...                                                   ...
# 115066  [Carcass, DevilDriver, Slipknot, Deicide, Arch...
# 115067  [Flatland Funk, Komes, Bsharry, Ste Ingham, Sp...
# 115068  [씨야, 가비엔제이, 윤종신, 김창기, 벤, 김진호 (SG워너비), 양희은, 나비,...
# 115069  [Angus & Julia Stone, Ben Howard, BØRNS, The S...
# 115070  [Jason Mraz, Acceptance, Mr. Probz, Paramore, ...
#
# [115071 rows x 2 columns]

# %%
train_df['artist_cnt'] = train_df['artist_list'].map(lambda x : len(x))
train_df.head(1)
# Out:
#       id plylst_title                                              songs  \
# 0  61281      여행같은 음악  [525514, 129701, 383374, 562083, 297861, 13954...
#
#                                          artist_list  artist_cnt
# 0  [Lily Of The Valley, Red Hot Chili Peppers, Co...          17

# %%
def list_merger(x) :
    temp_list.extend(x)

temp_list = []
train_df['artist_list'].map(list_merger)
unique_artists = list(set(temp_list))
num_artists = len(unique_artists)

# %%
print(num_artists)
print(sorted(unique_artists))
# Out:
# 99656
# ['', ' A.R.D.I.', ' Al Kasha', ' Benny Benassi', ' Black Pata', ' Budapest Failoni Chamber Orchestra', ' Chloe Martin', ' Coa White', ' Coro Del Teatro Alla Scala, Milano', ' Curbi', ' DJ Deeon', ' DJ True', ' David Lloyd-Jones', ' Dbrown', ' English Northern Philharmonia', ' Frank Tate', ' Hungarian State Opera Orchestra', ' Irish Film Orchestra', ' Lazy Hammock', ' Leonard Bernstein', ' MC Meta', ' Moon Rocket', ' Mugwanti', ' New Zealand Symphony Orchestra', ' Penn Masala', ' Prague Chamber Orchestra', ' ROSTAM', ' Raven & Kreyn', ' Richard Earnshaw', ' Robert Koenig', ' Roman Polonsky', ' Rostam', ' Scotty', ' Sigridur Nielsdottir', ' Simon Watkin', ' SkyKeeper', ' Swonderful Orchestra', ' Tara McDonald', ' Teairra Marie', ' The Bassalindos', ' The Rare Birds', ' The Rude Boy Of House', ' The Subs', ' Tiff Lacey', ' Ulster Orchestra', ' Vengeance', ' Wiener Singakademie', ' William Butt', ' William Naraine', ' Ying Yan Choir', ' monyamonya', ' 김민지', ' 임우(林雨)', '!!!', '!DelaDap', '!llmind', '!magnic!', '#Ash Simons', '#BONVIVANT', '#DAH', '#Esteve', '#Gun', '#TheSet', '#안녕', '$AN', '$B, Young Chris, King Trell', '$EUNGHYUN', '$HYBXI', '$KEETA', '$Lime', '$NOT', '$QUREL', '$UPRA', '$ain&#39;t junior', '$ammy (새미)', '$electo', '$ept Rabbit', '$hano', '$hany RP (샤니알피)', '$hredd', '$teven Cannon', '$tupid Young', '$ubjectz', '$uicideboy$', '$ylvia', '&#160;Yardbirds', '&#165;$&#8361;', '&#20904;田悠斗 / Yuuto Tomita', '&#214;d&#246;n R&#225;cz', '&#22885; 華子 / Hanako Oku', '&#24069;&#27668;&#27901;', '&#25993;藤由貴 / Yuki Saitou', '&#26686;&#36155;&#27901; (루안이저)', '&#27497;乃華', '&#27810;村&#26628;純 / Sawamura Eijun', '&#27973;野まゆみ / Asumi Nakata', '&#27973;野まゆみ / Lucia Nanami', '&#28165;水一登 / Kazuto Shimizu', '&#28381;川', '&#28783;油 / Touyu', '&#30740;ナオコ / Naoko Ken', '&#34;The Phantom Of The Opera&#34; Original London Cast', '&#37011;海&#29756; (Haiqiong Deng), 尹群 (Qun Yin) and 崔&#38745;怡 (Jingyi Cui)', '(+44)', '(.phelix)', '(hed) pe', '(여자)아이들', '(지범)ZEEBOMB', '*repeat repeat', '+36', '+Plus', '-Jose', '.(dot)any', '...And You Will Know Us By The Trail Of Dead', '...Whatever That Means', '...and Oceans', '.anxious.', '.com (닷컴)', '.gif', '.ihaveaface', '0&#39;CLASS', '0.125', '007코리아 (이원석, 이지형, 권정열)', '01', '010', '012', '015B', '02', '0208 Crew', '03 Greedo', '03소1059', '0405', '070 Shake', '0720', '0800', '0801Ni209336', '0820', '0PD', '0Pilot (영파일럿)', '0`clock', '0to0', '0프로', '1 Giant Leap', '1 Girl Nation', '1 Pound Fish Man', '1 World', '1%', '1,2,3', '1-800-lost', '1.B.T.H', '10 Rapid', '10 Stafford, Gordon McRae', '10 Years', '10 to 4', '10-Feet', '100 Cellos', '100 Gecs', '100%', '100% Backing Trax', '100% V', '1000 Beasts', '10000 Maniacs', '1000volts', '1004', '100989', '100KGOLD (허니케이골드)', '101', '101 Strings Orchestra', '1010 Benja SL', '1012', '1017 Eskimo', '102 Boyz', '106 (a.k.a Smooth J)', '1073 워쉽', '108', '109', '10CM', '10K.Caash', '10LEC6', '10cc', '10cm x Humbert', '10miles (텐마일즈)', '10mill', '10분전', '10시 45분', '10월', '11 Acorn Lane', '11 Inch', '11 Medical Sound', '11 To 12', '1174', '11:11', '11도 (11Degrees)', '11시11분', '11월', '11월 9일', '11호', '12 Ensemble', '12 Fingers', '12 Gauge', '12 Stones', '120', '1200 Micrograms', '120성령의 사람들', '120성령의사람들', '123Mrk', '1253 (일이오삼)', '12Til', '12hertz', '12pm', '12th Planet', '12月', '12월 愛 동물원', '13', '13 Winters', '13 스텝스', '1349', '13Seconds', '13Tries', '13lush', '13nichinokinyoubi', '13월 (13TH MONTH)', '13층', '1415', '143', '143am', '14?', '14U (원포유)', '14anger & Dep Affect', '15& (박지민, 백예린)', '1516', '153', '164', '169', '16os', '16yrold', '17 Memphis', '170hz', '1759orchid', '175R', '1773', '1788-L', '1801', '183 Club', '1833 AD', '187', '187 LOCKDOWN', '18Cruk', '18GRAM', '18th Letter', '19', '19 (NANA)', '1910 Fruitgum Company', '1910 Worship', '1950', '1972', '1973', '1976', '1979', '1984', '1985', '1987', '1990s', '1991', '1994', '1995', '19EIGHTY7', '19XX', '19세', '1AM', '1DB (원디비)', '1F (퍼스트플로어)', '1K (일케이)', '1K Phew', '1Kyne', '1L2L', '1MILLION', '1N1' ...

# %%
artist_to_id = {}

id_to_artist = {}

for i,v in enumerate(unique_artists):
    id_to_artist[i] = v
    
artist_to_id = {v:k for k,v in id_to_artist.items()}

def artist_id_trans(x):
    temp_list = []
    for artist in x : 
        temp_list.append(artist_to_id[artist])
    
    return temp_list
train_df['artist_id'] = train_df['artist_list'].map(artist_id_trans)

# %%
train_df.head(1)
# Out:
#       id plylst_title                                              songs  \
# 0  61281      여행같은 음악  [525514, 129701, 383374, 562083, 297861, 13954...
#
#                                          artist_list  artist_cnt  \
# 0  [Lily Of The Valley, Red Hot Chili Peppers, Co...          17
#
#                                            artist_id
# 0  [51388, 87460, 71903, 78840, 86864, 68964, 971...
