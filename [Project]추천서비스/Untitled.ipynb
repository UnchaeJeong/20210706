# %%
import pandas as pd
import json

# %%
temp = pd.read_json('data/user-report-export (3).json', encoding='utf-8-sig')
temp

with open('data/user-report-export (3).json',encoding='utf-8-sig') as f:
    temp_json = json.load(f)

# %%
date=[]
time=[]
for i in range(len(temp_json[1])):
    date.append(temp_json[1][i]["date"])
    value.append(temp_json[1][i]["value"])
#     unit.append(temp_json[1][i]["unit"])
#     obs_status.append(temp_json[1][i]["obs_status"])
#     decimal.append(temp_json[1][i]["decimal"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-ec55cf45608b> in <module>
#       1 date=[]
#       2 time=[]
# ----> 3 for i in range(len(temp_json[1])):
#       4     date.append(temp_json[1][i]["date"])
#       5     value.append(temp_json[1][i]["value"])
#
# KeyError: 1

# %%
temp_json
# Out:
# {'dates': [{'date': '11월 5, 2021',
#    'hasGoal': False,
#    'hasRevenue': False,
#    'sessionCount': 4,
#    'sessions': [{'duration': '00:09',
#      'deviceCategory': 'desktop',
#      'channel': 'Direct',
#      'activitySummary': {'EVENT': '5', 'PAGEVIEW': '2'},
#      'activities': [{'time': '8:08 오후',
#        'type': 'EVENT',
#        'repeatActivityTimes': [],
#        'details': [{'이벤트 카테고리': ['스크롤'],
#          '이벤트 액션': ['스크롤 트래킹'],
#          '이벤트 라벨': ['http://54.180.196.91:8080/'],
#          '이벤트 수': ['1'],
#          '이벤트 값': ['0']}],
#        'name': '스크롤 트래킹',
#        'on': '스크롤'},
#       {'time': '8:08 오후',
#        'type': 'EVENT',
#        'repeatActivityTimes': [],
#        'details': [{'이벤트 카테고리': ['스크롤'],
#          '이벤트 액션': ['스크롤 트래킹'],
#          '이벤트 라벨': ['http://54.180.196.91:8080/'],
#          '이벤트 수': ['1'],
#          '이벤트 값': ['0']}],
#        'name': '스크롤 트래킹',
#        'on': '스크롤'},
#       {'time': '8:08 오후',
#        'type': 'PAGEVIEW',
# ...

# %%
temp_json['dates'][]
# Out:
# {'date': '11월 5, 2021',
#  'hasGoal': False,
#  'hasRevenue': False,
#  'sessionCount': 4,
#  'sessions': [{'duration': '00:09',
#    'deviceCategory': 'desktop',
#    'channel': 'Direct',
#    'activitySummary': {'EVENT': '5', 'PAGEVIEW': '2'},
#    'activities': [{'time': '8:08 오후',
#      'type': 'EVENT',
#      'repeatActivityTimes': [],
#      'details': [{'이벤트 카테고리': ['스크롤'],
#        '이벤트 액션': ['스크롤 트래킹'],
#        '이벤트 라벨': ['http://54.180.196.91:8080/'],
#        '이벤트 수': ['1'],
#        '이벤트 값': ['0']}],
#      'name': '스크롤 트래킹',
#      'on': '스크롤'},
#     {'time': '8:08 오후',
#      'type': 'EVENT',
#      'repeatActivityTimes': [],
#      'details': [{'이벤트 카테고리': ['스크롤'],
#        '이벤트 액션': ['스크롤 트래킹'],
#        '이벤트 라벨': ['http://54.180.196.91:8080/'],
#        '이벤트 수': ['1'],
#        '이벤트 값': ['0']}],
#      'name': '스크롤 트래킹',
#      'on': '스크롤'},
#     {'time': '8:08 오후',
#      'type': 'PAGEVIEW',
#      'repeatActivityTimes': [],
# ...

# %%
date=[]
value=[]
unit=[]
obs_status=[]
decimal=[]
for i in range(len(contents[1])):
    date.append(contents[1][i]["date"])
    value.append(contents[1][i]["value"])
    unit.append(contents[1][i]["unit"])
    obs_status.append(contents[1][i]["obs_status"])
    decimal.append(contents[1][i]["decimal"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-82c526bb5ae8> in <module>
#       4 obs_status=[]
#       5 decimal=[]
# ----> 6 for i in range(len(contents[1])):
#       7     date.append(contents[1][i]["date"])
#       8     value.append(contents[1][i]["value"])
#
# NameError: name 'contents' is not defined
