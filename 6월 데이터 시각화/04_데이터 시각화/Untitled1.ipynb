# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pandas as pd

#그래프를 그리기 위한 기본 설정
#폰트 설정 - 윈도우
plt.rcParams['font.family'] = 'Malgun Gothic'
# 폰트 설정 - 맥
# plt.rcParams['font.family'] = 'AppleGothic'

#그래프의 크기
plt.rcParams['figure.figsize'] = 12, 6

#글자 크기
plt.rcParams['font.size'] = 14

#폰트 설정 시 - 기호 깨지는 것 방지하기
plt.rcParams['axes.unicode_minus'] = False

plt.rcParams['figure.facecolor'] = 'white'

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
plt.plot([1,2,3,4])

# %%
plt.plot([10,20,30,40],[1,2,3,4])
plt.show()

# %%
plt.plot([10,20,30,40],[1,4,9,16], 'b^:')
plt.xlabel('x')
plt.ylabel('y')
plt.xlim(5,50)
plt.ylim(0,20)
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=np.arange(0,10,0.01)

# %%
plt.subplot(211);plt.plot(np.sin(x),'r')
plt.subplot(223);plt.plot(np.sin(x),'b')
plt.subplot(224);plt.plot(np.cos(x),'g')
plt.show()

# %%
fig, axes = plt.subplots(nrows=2,ncols=2)
axes[1,1].plot(x, np.sin(x))
plt.show()

# %%
def sin_cos(x):
    return np.sin(x)*np.cos(x)

func_list = [np.sin, np.cos, np.tanh, sin_cos]

fig, axes = plt.subplots(nrows=2, ncols=2)
for i, ax in enumerate(axes.flat):
    ax.plot(x, func_list[i](x))

plt.show()

# %%
fig, axex = plt.subplots(2,2,figsize=(12,6))

# %%
X = np.linspace(-np.pi, np.pi, 256)
y1 = np.cos(X)
y2 = np.sin(X)

plt.plot(X, y1, ls='--', label='cosine')
plt.plot(X, y2, ls='--', label='sine')
plt.legend(loc=1)
plt.show()

# %%
X = [1,2,3]
Y = [2,3,1]
plt.title('선그래프')
plt.barh(X,Y)

# plt.xticks([1,2,3], ['a','b','c'])
# plt.yticks([0,2,10],['d','e','f'])

plt.xlabel('x')
plt.ylabel('y')

plt.show()

# %%
x = np.linspace(0.1, 2*np.pi, 10)
y = np.cos(x)
y

plt.stem(x, y, '-.')
plt.show()

# %%
values = [15,30,40,10]
labels = ['1', '2', '3', '4']
explode = [0,0,2,0]
plt.title('pie')
plt.pie(values, labels=labels, explode=[0,0,0.3,0], shadow=True, startangle=90, counterclock=False,
       autopct='%.2f%%')
plt.show()

# %%
x = np.random.rand(1000)

plt.title('hist')
plt.hist(x, bins=30)
plt.show()

# %%
x = np.random.rand(100)
y = np.random.rand(100)

x2 = np.random.rand(100)
y2 = np.random.rand(100)

plt.title('scatter')
plt.scatter(x,y)
plt.scatter(x2,y2)
plt.show()

# %%
x = np.random.randn(100,3)
index = pd.date_range('2021/01/01', periods=100)

df1 = pd.DataFrame(x, index = index, columns = ['a','b','c'])
df1
# Out:
#                    a         b         c
# 2021-01-01 -0.687242  0.709265  0.826242
# 2021-01-02 -1.518992 -0.218005  1.167258
# 2021-01-03 -1.191566  1.034707  0.243119
# 2021-01-04  0.882687  1.225734 -1.432352
# 2021-01-05  0.415862 -1.319425  2.218357
# ...              ...       ...       ...
# 2021-04-06 -1.029366  0.081487  2.869738
# 2021-04-07  0.026236  0.058301  1.078422
# 2021-04-08  0.672970 -0.340254 -1.713622
# 2021-04-09 -0.601072  0.091316  3.765585
# 2021-04-10  1.075251 -0.863988 -1.255847
#
# [100 rows x 3 columns]

# %%
df1.plot()
plt.title('line')
plt.xlabel('time')
plt.ylabel('labels')
plt.show()

# %%
iris = pd.read_csv('data/iris.csv')
iris.columns = ['sl','sw','pl','pw','target']
iris
# Out:
#       sl   sw   pl   pw     target
# 0    5.1  3.5  1.4  0.2     setosa
# 1    4.9  3.0  1.4  0.2     setosa
# 2    4.7  3.2  1.3  0.2     setosa
# 3    4.6  3.1  1.5  0.2     setosa
# 4    5.0  3.6  1.4  0.2     setosa
# ..   ...  ...  ...  ...        ...
# 145  6.7  3.0  5.2  2.3  virginica
# 146  6.3  2.5  5.0  1.9  virginica
# 147  6.5  3.0  5.2  2.0  virginica
# 148  6.2  3.4  5.4  2.3  virginica
# 149  5.9  3.0  5.1  1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris['pw'][:20].plot(kind='bar')
plt.title('sl')
plt.show()

# %%
iris['sw'][:20].plot.bar()
plt.show()

# %%
df2 = iris.drop('target', axis=1)
df2[:10].plot.bar()
plt.show()

# %%
df2 = iris.groupby('target', axis=1)

# %%
df2 = iris.drop('target', axis=1)
df2.head(20).plot.bar()
plt.show()

# %%
a1 = iris.groupby('target').mean()
a1.plot.bar()
plt.show()
iris
# Out:
#       sl   sw   pl   pw     target
# 0    5.1  3.5  1.4  0.2     setosa
# 1    4.9  3.0  1.4  0.2     setosa
# 2    4.7  3.2  1.3  0.2     setosa
# 3    4.6  3.1  1.5  0.2     setosa
# 4    5.0  3.6  1.4  0.2     setosa
# ..   ...  ...  ...  ...        ...
# 145  6.7  3.0  5.2  2.3  virginica
# 146  6.3  2.5  5.0  1.9  virginica
# 147  6.5  3.0  5.2  2.0  virginica
# 148  6.2  3.4  5.4  2.3  virginica
# 149  5.9  3.0  5.1  1.8  virginica
#
# [150 rows x 5 columns]

# %%
a1 = iris['target'].value_counts()
a1.plot.pie(explode=[0,0,0.1],autopct='%.2f%%',startangle=90, counterclock=False)
plt.title('품종 별 라벨 비율')
plt.show()

# %%
iris.plot.hist()
plt.show()

# %%
iris.plot.kde()
plt.show()

# %%
iris.plot.box(grid=True)
plt.show()

# %%
iris.boxplot()
plt.show()

# %%
import seaborn as sns

# %%
sns.rugplot(iris['sw'],)
plt.title('sw')
plt.show()

# %%
sns.kdeplot(iris['sw'])
plt.title('kde')
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

sns.distplot(iris['sw'], kde=True, rug=True)
plt.title('distplot')
plt.show()

# %%
sns.histplot(iris['pw'], kde=True)
plt.title('histplot')
plt.show()

# %%
sns.countplot(data = iris, x='target')
plt.title('countplot')
plt.show()

# %%
sns.jointplot(x='sw', y='pw', data=iris, hue='target')
plt.suptitle('joint plot', y=1.02)
plt.show()

# %%
sns.jointplot(x='sw', y='pw',kind='kde', data=iris, hue='target')
plt.suptitle('joint kde', y=1.02)
plt.show()

# %%
sns.pairplot(data=iris, hue='target')
plt.suptitle('pairplot', y=1.02)
plt.show()
